# %%
import pandas as pd

# %%
pd.set_option( 'display.max_columns', None )
pd.set_option( 'display.max_rows', None )
def get_data( path ):
    read_data = pd.read_excel( path )
    return read_data


data = get_data( 'Vendas.xlsx' )
data['ano'] = data['Data'].dt.strftime( '%y' )
display( data.head( 10 ) )
# Out:
#    Código Venda       Data                     ID Loja  \
# 0             1 2019-01-01          Iguatemi Esplanada
# 1             1 2019-01-01          Iguatemi Esplanada
# 2             1 2019-01-01          Iguatemi Esplanada
# 3             2 2019-01-02              Norte Shopping
# 4             2 2019-01-02              Norte Shopping
# 5             3 2019-01-02  Rio Mar Shopping Fortaleza
# 6             5 2019-01-02              Shopping Barra
# 7             6 2019-01-02         Shopping Ibirapuera
# 8             7 2019-01-02              Norte Shopping
# 9             7 2019-01-02              Norte Shopping
#
#                   Produto  Quantidade  Valor Unitário  Valor Final ano
# 0          Sapato Estampa           1             358          358  19
# 1                Camiseta           2             180          360  19
# 2           Sapato Xadrez           1             368          368  19
# 3                 Relógio           3             200          600  19
# ...

# %%
faturamento = data[['ID Loja', 'Valor Final']].groupby('ID Loja').sum()

quantidade = data[['ID Loja', 'Quantidade']].groupby('ID Loja').sum()

ticket_medio = (faturamento['Valor Final'] / quantidade['Quantidade'])
ticket_medio = pd.DataFrame(ticket_medio, columns=['Ticket médio'])

# %%
merge1 = pd.merge(faturamento, quantidade, how='inner', on= 'ID Loja').reset_index()
merge2 = pd.merge(merge1, ticket_medio, how='inner', on='ID Loja').reset_index()
display(merge2)
# Out:
#     index                           ID Loja  Valor Final  Quantidade  \
# 0       0               Bourbon Shopping SP      1726110        8863
# 1       1        Center Shopping Uberlândia      1668921        8627
# 2       2                 Iguatemi Campinas      1762419        8935
# 3       3                Iguatemi Esplanada      1699681        8580
# 4       4                    Norte Shopping      1711968        9014
# 5       5      Novo Shopping Ribeirão Preto      1678225        8751
# 6       6       Palladium Shopping Curitiba      1721120        9091
# 7       7         Parque Dom Pedro Shopping      1631630        8388
# 8       8         Passei das Águas Shopping      1649014        8618
# 9       9                 Ribeirão Shopping      1707122        8825
# 10     10                    Rio Mar Recife      1722766        8863
# 11     11        Rio Mar Shopping Fortaleza      1698430        8937
# 12     12                 Salvador Shopping      1646739        8698
# ...
